# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = pd.read_csv('titanic_data.csv')

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## No of males and females present on the ship ##

# %%
titanic_df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.scatter

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-a45db67b0195> in <module>
# ----> 1 res = titanic_df['Age'].apply(checkNan)
#       2 res
#
# c:\users\rattlesnakes\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4133             else:
#    4134                 values = self.astype(object)._values
# -> 4135                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4136
#    4137         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-52-f2251449d48c> in checkNan(num)
#       2
#       3 def checkNan(num):
# ----> 4     if(num.isnan()):
#       5         num = mean_age
#       6     else:
#
# AttributeError: 'float' object has no attribute 'isnan'

# %% [markdown]
# ## People embarked from three places ##
# - Southampton - 644
# - Cherbourg - 168
# - Queenstown - 77

# %%
titanic_df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic_df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
survived_passengers = titanic_df[titanic_df['Survived'] == 1]
n_survived_passengers = titanic_df[titanic_df['Survived'] == 0]

# %% [markdown]
# ## Finding mean age of passengers who survived

# %%
survived_passengers.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   342.000000     342.0  342.000000  290.000000  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.343690    0.473684    0.464912
# std     252.358840       0.0    0.863321   14.950952    0.708688    0.771712
# min       2.000000       1.0    1.000000    0.420000    0.000000    0.000000
# 25%     250.750000       1.0    1.000000   19.000000    0.000000    0.000000
# 50%     439.500000       1.0    2.000000   28.000000    0.000000    0.000000
# 75%     651.500000       1.0    3.000000   36.000000    1.000000    1.000000
# max     890.000000       1.0    3.000000   80.000000    4.000000    5.000000
#
#              Fare
# count  342.000000
# mean    48.395408
# std     66.596998
# min      0.000000
# 25%     12.475000
# 50%     26.000000
# 75%     57.000000
# max    512.329200

# %%
n_survived_passengers.describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   549.000000     549.0  549.000000  424.000000  549.000000  549.000000
# mean    447.016393       0.0    2.531876   30.626179    0.553734    0.329690
# std     260.640469       0.0    0.735805   14.172110    1.288399    0.823166
# min       1.000000       0.0    1.000000    1.000000    0.000000    0.000000
# 25%     211.000000       0.0    2.000000   21.000000    0.000000    0.000000
# 50%     455.000000       0.0    3.000000   28.000000    0.000000    0.000000
# 75%     675.000000       0.0    3.000000   39.000000    1.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    8.000000    6.000000
#
#              Fare
# count  549.000000
# mean    22.117887
# std     31.388207
# min      0.000000
# 25%      7.854200
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %%
n_survived_passengers.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000       NaN  0.051184  0.017284 -0.067959 -0.015871
# Survived             NaN       NaN       NaN       NaN       NaN       NaN
# Pclass          0.051184       NaN  1.000000 -0.434168  0.125714  0.068482
# Age             0.017284       NaN -0.434168  1.000000 -0.403734 -0.096298
# SibSp          -0.067959       NaN  0.125714 -0.403734  1.000000  0.477940
# Parch          -0.015871       NaN  0.068482 -0.096298  0.477940  1.000000
# Fare           -0.084730       NaN -0.517378  0.076852  0.282108  0.347307
#
#                  Fare
# PassengerId -0.084730
# Survived          NaN
# Pclass      -0.517378
# Age          0.076852
# SibSp        0.282108
# Parch        0.347307
# Fare         1.000000

# %%
fig = plt.figure()
axis = fig.add_axes([0,0,1,1])
axis.plot(n_survived_passengers['Fare'],n_survived_passengers['Pclass'],label="Plot of Fare vs Passenger class")
axis.set_xlabel('Fare')
axis.set_ylabel('Pclass')
# Out:
# Text(0, 0.5, 'Pclass')

# %%
titanic_df[['Fare','Pclass']]
# Out:
#         Fare  Pclass
# 0     7.2500       3
# 1    71.2833       1
# 2     7.9250       3
# 3    53.1000       1
# 4     8.0500       3
# ..       ...     ...
# 886  13.0000       2
# 887  30.0000       1
# 888  23.4500       3
# 889  30.0000       1
# 890   7.7500       3
#
# [891 rows x 2 columns]

# %%
sns.scatterplot(data = titanic_df[['Fare','Pclass']],x='Fare',y='Pclass',hue = 'Pclass',style='Fare')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Pclass'>
